# %%
import pandas as pd
from dstoolkit import Univariate

# %%
dataset = pd.read_csv('Placement.csv')

# %%
quan,qual = Univariate.quanQual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
freqTable = Univariate.freqTable('salary',dataset)

# %%
freqTable
# Out:
#     Unique_Values  Frequency  Relative Frequency    Cumsum
# 0        300000.0         22            0.213592  0.213592
# 1        250000.0         18            0.174757  0.388350
# 2        240000.0         15            0.145631  0.533981
# 3        260000.0          7            0.067961  0.601942
# 4        360000.0          6            0.058252  0.660194
# 5        200000.0          6            0.058252  0.718447
# 6        265000.0          6            0.058252  0.776699
# 7        220000.0          5            0.048544  0.825243
# 8        275000.0          5            0.048544  0.873786
# 9        210000.0          4            0.038835  0.912621
# 10       400000.0          4            0.038835  0.951456
# 11       270000.0          4            0.038835  0.990291
# 12       216000.0          3            0.029126  1.019417
# 13       350000.0          3            0.029126  1.048544
# 14       500000.0          3            0.029126  1.077670
# ...

# %%
descriptive_analysis = Univariate.describe(dataset)

# %%
descriptive_analysis
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# 99%        NaN        NaN        NaN        NaN        NaN        NaN
# Q4:100%  215.0       89.4       97.7       91.0       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule  160.5      22.65      18.15       16.5      35.25     12.465
# Lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# Greater  322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %%
Univariate.pdf(dataset["ssc_p"],80,80)
# Out:
# Mean=67.303, Standard Deviation=10.827
# The area between range(80,80):0
# 0

# %%
outliers = Univariate.check_outliers(dataset)

# %%
outliers
# Out:
#      column  lower_bound  upper_bound  num_outliers  \
# 0     sl_no      -106.00       322.00             0
# 1     ssc_p        37.95        98.35             0
# 2     hsc_p        42.75        91.15             8
# 3  degree_p        44.50        88.50             1
# 4   etest_p        24.75       118.75             0
# 5     mba_p        45.48        78.72             0
# 6    salary    150000.00    390000.00            15
#
#                                     outliers_indices
# 0                                                 []
# 1                                                 []
# 2              [24, 42, 49, 120, 134, 169, 177, 206]
# 3                                              [197]
# 4                                                 []
# 5                                                 []
# 6  [4, 21, 39, 53, 77, 85, 95, 119, 128, 145, 150...

# %%
dataset = Univariate.clean_num_outlier(dataset)

# %%
Univariate.check_outliers(dataset)
# Out:
#      column  lower_bound  upper_bound  num_outliers outliers_indices
# 0     sl_no      -106.00       322.00             0               []
# 1     ssc_p        37.95        98.35             0               []
# 2     hsc_p        42.75        91.15             0               []
# 3  degree_p        44.50        88.50             0               []
# 4   etest_p        24.75       118.75             0               []
# 5     mba_p        45.48        78.72             0               []
# 6    salary    150000.00    390000.00             0               []

# %%
Univariate.z_score(dataset['ssc_p'])

# %%
Univariate.analyse(dataset, 'etest_p')
# Out:
# Description of etest_p
# ----------------------------------------------------------------------------
# count    215.000000
# mean      72.100558
# std       13.275956
# min       50.000000
# 25%       60.000000
# 50%       71.000000
# 75%       83.500000
# max       98.000000
# Name: etest_p, dtype: float64
# Central values of etest_p
# ----------------------------------------------------------------------------
#
# Minimum :  50.0
# Maximum :  98.0
# Mean value :  72.10055813953488
# Median value :  71.0
# Standard deviation :  13.275956401653835
# Null values :  False
# Null values :  0
# Quartile of etest_p
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  60.0
# 3st Quartile (Q3) is:  83.5
# Interquartile range (IQR) is  23.5
#
# Outlier detection from Interquartile range (IQR) etest_p
# ----------------------------------------------------------------------------
#
# Lower outliers range:  24.75
#
# ...
